# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 100
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 100:
# Image - Min Value: 15 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    return np.array( (x - np.min(x)) / (np.max(x) - np.min(x)) )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    one_hot = np.zeros(shape=(len(x), 10))
    for i in range(len(x)):
        for j in range(10):
            one_hot[i][j] = (j == x[i])
    return one_hot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, shape=[None, *image_shape], name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, n_classes], name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # weight and bias
    weight = tf.Variable(tf.random_normal([*conv_ksize, tf.to_int32(x_tensor.get_shape().as_list()[3]), conv_num_outputs], mean=0.0, stddev=0.01))
    bias = tf.Variable (tf.zeros(conv_num_outputs))

    conv_strides_list = [1, conv_strides[0], conv_strides[1], 1]

    conv_layer = tf.nn.conv2d (tf.to_float(x_tensor), weight, strides = conv_strides_list, padding = 'SAME')
    conv_layer = tf.nn.bias_add (conv_layer, bias)
    conv_layer = tf.nn.relu (conv_layer)

    pool_ksize_list = [1, pool_ksize[0], pool_ksize[1], 1]
    pool_strides_list = [1, pool_strides[0], pool_strides[1], 1]

    max_pool_layer = tf.nn.max_pool (conv_layer, pool_ksize_list, pool_strides_list, padding = 'SAME')

    return max_pool_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    w,h,d = (x_tensor.get_shape().as_list()[1:4])
    return tf.reshape(x_tensor, [-1,w*h*d])
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
      
    weights = tf.Variable(tf.truncated_normal(
        [int(x_tensor.shape[1]), num_outputs],
        mean=0.0,
        stddev=0.1,
        dtype=tf.float32))
    
    bias = tf.Variable(tf.zeros(num_outputs))
    
    fc1 = tf.add(tf.matmul(x_tensor, weights), bias)
    fc1 = tf.nn.relu(fc1)
    return fc1


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    
    # get the nbumber of outputs from x_tensor
    tensor_outputs = x_tensor.get_shape().as_list()[1]
    
    weights = tf.Variable(tf.random_normal([tensor_outputs, num_outputs], mean=0.0, stddev=0.01))
    bias = tf.Variable (tf.zeros(num_outputs))
    
    output_layer = tf.add(tf.matmul(x_tensor, weights), bias)
    return output_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x_tensor = x
    conv_num_outputs = 96
    conv_ksize = (4, 4)
    conv_strides = (2, 2)
    pool_ksize = (4, 4)
    pool_strides = (2, 2)
    
    x_tensor = conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
        

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    x_tensor = flatten(x_tensor)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    num_outputs = 52    
    x_tensor = fully_conn(x_tensor, num_outputs)
    x_tensor = tf.nn.dropout(x_tensor, keep_prob)
        
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    num_outputs = 10
    x_tensor = output(x_tensor, num_outputs)
    
    
    # TODO: return output
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
       x: feature_batch,
       y: label_batch,
       keep_prob: keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.0})
    
    valid_acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.0})
    
    print('Loss: {:>10.4f} Accuracy: {:.6f}'.format(loss,valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 1024
keep_probability = 0.7

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2783 Accuracy: 0.136800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.1620 Accuracy: 0.574000
# Epoch 19, CIFAR-10 Batch 2:  Loss:     1.1389 Accuracy: 0.574800
# Epoch 19, CIFAR-10 Batch 3:  Loss:     1.1213 Accuracy: 0.573600
# Epoch 19, CIFAR-10 Batch 4:  Loss:     1.1132 Accuracy: 0.576600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     1.1391 Accuracy: 0.574400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.1423 Accuracy: 0.576000
# Epoch 20, CIFAR-10 Batch 2:  Loss:     1.1312 Accuracy: 0.581200
# Epoch 20, CIFAR-10 Batch 3:  Loss:     1.1105 Accuracy: 0.578200
# Epoch 20, CIFAR-10 Batch 4:  Loss:     1.1077 Accuracy: 0.579600
# Epoch 20, CIFAR-10 Batch 5:  Loss:     1.1288 Accuracy: 0.581800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.1364 Accuracy: 0.583000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     1.1123 Accuracy: 0.584600
# Epoch 21, CIFAR-10 Batch 3:  Loss:     1.0891 Accuracy: 0.585400
# Epoch 21, CIFAR-10 Batch 4:  Loss:     1.0885 Accuracy: 0.589000
# Epoch 21, CIFAR-10 Batch 5:  Loss:     1.1116 Accuracy: 0.588000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.1304 Accuracy: 0.585600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     1.1041 Accuracy: 0.586400
# Epoch 22, CIFAR-10 Batch 3:  Loss:     1.0884 Accuracy: 0.584000
# Epoch 22, CIFAR-10 Batch 4:  Loss:     1.0781 Accuracy: 0.586600
# Epoch 22, CIFAR-10 Batch 5:  Loss:     1.1041 Accuracy: 0.590600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.1143 Accuracy: 0.589200
# Epoch 23, CIFAR-10 Batch 2:  Loss:     1.0922 Accuracy: 0.591200
# Epoch 23, CIFAR-10 Batch 3:  Loss:     1.0661 Accuracy: 0.595400
# Epoch 23, CIFAR-10 Batch 4:  Loss:     1.0678 Accuracy: 0.596800
# Epoch 23, CIFAR-10 Batch 5:  Loss:     1.0866 Accuracy: 0.590600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.0969 Accuracy: 0.598400
# Epoch 24, CIFAR-10 Batch 2:  Loss:     1.0730 Accuracy: 0.597800
# Epoch 24, CIFAR-10 Batch 3:  Loss:     1.0622 Accuracy: 0.592000
# Epoch 24, CIFAR-10 Batch 4:  Loss:     1.0582 Accuracy: 0.598800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     1.0644 Accuracy: 0.598200
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.0892 Accuracy: 0.596600
# Epoch 25, CIFAR-10 Batch 2:  Loss:     1.0552 Accuracy: 0.599000
# Epoch 25, CIFAR-10 Batch 3:  Loss:     1.0442 Accuracy: 0.597200
# Epoch 25, CIFAR-10 Batch 4:  Loss:     1.0424 Accuracy: 0.607600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     1.0475 Accuracy: 0.600200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.0813 Accuracy: 0.599200
# Epoch 26, CIFAR-10 Batch 2:  Loss:     1.0546 Accuracy: 0.598200
# Epoch 26, CIFAR-10 Batch 3:  Loss:     1.0411 Accuracy: 0.602400
# Epoch 26, CIFAR-10 Batch 4:  Loss:     1.0520 Accuracy: 0.597400
# Epoch 26, CIFAR-10 Batch 5:  Loss:     1.0441 Accuracy: 0.603000
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.8643 Accuracy: 0.660400
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.8282 Accuracy: 0.657400
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.8179 Accuracy: 0.659200
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.8186 Accuracy: 0.657400
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.7962 Accuracy: 0.655400
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.8573 Accuracy: 0.657000
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.8179 Accuracy: 0.659200
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.8303 Accuracy: 0.654800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.8217 Accuracy: 0.661600
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.7964 Accuracy: 0.654800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.8435 Accuracy: 0.663400
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.8254 Accuracy: 0.658400
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.8455 Accuracy: 0.645200
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.8010 Accuracy: 0.656000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.7907 Accuracy: 0.656400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.8451 Accuracy: 0.661400
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.8144 Accuracy: 0.659200
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.8102 Accuracy: 0.655800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.8002 Accuracy: 0.653400
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.7856 Accuracy: 0.659200
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.8428 Accuracy: 0.659200
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.8131 Accuracy: 0.659200
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.8282 Accuracy: 0.650200
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.7980 Accuracy: 0.657400
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.7760 Accuracy: 0.656800
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.8366 Accuracy: 0.657000
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.8020 Accuracy: 0.662800
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.7923 Accuracy: 0.662600
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.7913 Accuracy: 0.657800
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.7641 Accuracy: 0.664000
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.8389 Accuracy: 0.663200
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.7822 Accuracy: 0.665400
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.7966 Accuracy: 0.661600
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.7850 Accuracy: 0.656600
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.7768 Accuracy: 0.659200
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.8533 Accuracy: 0.656800
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.7959 Accuracy: 0.662600
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.7887 Accuracy: 0.661600
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.7855 Accuracy: 0.658200
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.7633 Accuracy: 0.662400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.8149 Accuracy: 0.666200
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.7834 Accuracy: 0.664600
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.7791 Accuracy: 0.663000
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.7801 Accuracy: 0.662200
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.7608 Accuracy: 0.655200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.8266 Accuracy: 0.662400
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.7753 Accuracy: 0.666800
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.7666 Accuracy: 0.665600
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.7915 Accuracy: 0.654400
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.7473 Accuracy: 0.665800
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.8103 Accuracy: 0.663000
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.7726 Accuracy: 0.665800
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.7788 Accuracy: 0.664600
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.7818 Accuracy: 0.662600
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.7541 Accuracy: 0.662000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.8062 Accuracy: 0.660400
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.7678 Accuracy: 0.662400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.7681 Accuracy: 0.667800
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.7559 Accuracy: 0.663800
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.7338 Accuracy: 0.664000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.8094 Accuracy: 0.664200
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.7743 Accuracy: 0.657200
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.7656 Accuracy: 0.665600
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.7682 Accuracy: 0.659000
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.7370 Accuracy: 0.666000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.7902 Accuracy: 0.668800
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.7605 Accuracy: 0.669600
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.7584 Accuracy: 0.665200
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.7519 Accuracy: 0.666800
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.7244 Accuracy: 0.671600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.7980 Accuracy: 0.668600
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.7589 Accuracy: 0.664000
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.7496 Accuracy: 0.668800
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.7590 Accuracy: 0.656600
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.7245 Accuracy: 0.662400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.7830 Accuracy: 0.664800
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.7550 Accuracy: 0.663600
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.7424 Accuracy: 0.670000
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.7552 Accuracy: 0.657600
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.7174 Accuracy: 0.666000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.7773 Accuracy: 0.665600
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.7521 Accuracy: 0.666000
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.7426 Accuracy: 0.667400
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.7227 Accuracy: 0.669800
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.7232 Accuracy: 0.665800
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.7764 Accuracy: 0.667200
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.7489 Accuracy: 0.662400
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.7408 Accuracy: 0.670600
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.7384 Accuracy: 0.666400
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.7174 Accuracy: 0.668400
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.7724 Accuracy: 0.667800
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.7369 Accuracy: 0.670600
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.7497 Accuracy: 0.664800
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.7305 Accuracy: 0.662200
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.7026 Accuracy: 0.672400
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.7670 Accuracy: 0.670600
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.7471 Accuracy: 0.667400
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.7344 Accuracy: 0.666400
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.7132 Accuracy: 0.668800
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.6961 Accuracy: 0.674400
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.7575 Accuracy: 0.668600
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.7260 Accuracy: 0.673400
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.7301 Accuracy: 0.668200
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.7114 Accuracy: 0.671000
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.6947 Accuracy: 0.668800
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.7579 Accuracy: 0.673600
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.7143 Accuracy: 0.674000
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.7205 Accuracy: 0.670400
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.7150 Accuracy: 0.666600
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.6832 Accuracy: 0.672400
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.7401 Accuracy: 0.677400
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.7084 Accuracy: 0.674000
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.7438 Accuracy: 0.670000
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.7113 Accuracy: 0.666400
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.6811 Accuracy: 0.671000
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.7438 Accuracy: 0.675200
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.7193 Accuracy: 0.670600
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.7543 Accuracy: 0.662800
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.7022 Accuracy: 0.666400
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.6798 Accuracy: 0.669400
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.7508 Accuracy: 0.667200
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.7026 Accuracy: 0.672000
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.7195 Accuracy: 0.666200
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.7032 Accuracy: 0.671200
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.6765 Accuracy: 0.677200
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.7416 Accuracy: 0.670200
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.7006 Accuracy: 0.671400
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.7131 Accuracy: 0.664200
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.7219 Accuracy: 0.658600
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.6651 Accuracy: 0.680000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.7500 Accuracy: 0.674800
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.6954 Accuracy: 0.674600
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.7104 Accuracy: 0.668400
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.7175 Accuracy: 0.660600
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.6693 Accuracy: 0.680800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.7487 Accuracy: 0.672400
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.7182 Accuracy: 0.666800
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.7105 Accuracy: 0.671400
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.6907 Accuracy: 0.670200
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.6657 Accuracy: 0.672400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.7376 Accuracy: 0.680200
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.6897 Accuracy: 0.667000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.7224 Accuracy: 0.658800
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.7076 Accuracy: 0.661600
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.6636 Accuracy: 0.676200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.7338 Accuracy: 0.674600
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.6830 Accuracy: 0.674600
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.7018 Accuracy: 0.667000
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.7071 Accuracy: 0.665000
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.6462 Accuracy: 0.680200
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.7244 Accuracy: 0.676400
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.6856 Accuracy: 0.674000
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.6902 Accuracy: 0.673000
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.6884 Accuracy: 0.663600
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.6651 Accuracy: 0.673400
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.7426 Accuracy: 0.673800
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.6860 Accuracy: 0.675200
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.6739 Accuracy: 0.679000
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.6777 Accuracy: 0.678000
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.6492 Accuracy: 0.677800
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.7329 Accuracy: 0.675800
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.6817 Accuracy: 0.669400
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.6784 Accuracy: 0.675000
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.6888 Accuracy: 0.664600
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.6432 Accuracy: 0.675800
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.7212 Accuracy: 0.679800
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.6753 Accuracy: 0.678000
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.6726 Accuracy: 0.683200
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.6908 Accuracy: 0.668400
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.6383 Accuracy: 0.676600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.7163 Accuracy: 0.679200
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.6678 Accuracy: 0.671800
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.6647 Accuracy: 0.680600
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.6774 Accuracy: 0.674400
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.6422 Accuracy: 0.674800
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.7006 Accuracy: 0.680600
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.6707 Accuracy: 0.678000
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.6687 Accuracy: 0.678400
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.6757 Accuracy: 0.674600
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.6389 Accuracy: 0.667000
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.6982 Accuracy: 0.681200
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.6846 Accuracy: 0.668600
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.6800 Accuracy: 0.673400
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.6601 Accuracy: 0.680600
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.6199 Accuracy: 0.670400
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.6891 Accuracy: 0.679800
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.6610 Accuracy: 0.673000
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.6871 Accuracy: 0.673200
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.6584 Accuracy: 0.674400
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.6270 Accuracy: 0.672400
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.6787 Accuracy: 0.680400
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.6473 Accuracy: 0.676000
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.6961 Accuracy: 0.668800
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.6520 Accuracy: 0.676000
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.6235 Accuracy: 0.678400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.6881 Accuracy: 0.678600
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.6482 Accuracy: 0.673400
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.6694 Accuracy: 0.680200
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.6526 Accuracy: 0.676800
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.6069 Accuracy: 0.680600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.6798 Accuracy: 0.682600
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.6394 Accuracy: 0.677200
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.6690 Accuracy: 0.673600
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.6441 Accuracy: 0.673200
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.6061 Accuracy: 0.678000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.6789 Accuracy: 0.680000
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.6333 Accuracy: 0.673200
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.6558 Accuracy: 0.674200
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.6421 Accuracy: 0.678800
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.6036 Accuracy: 0.681800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.6779 Accuracy: 0.683600
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.6281 Accuracy: 0.674800
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.6548 Accuracy: 0.678400
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.6523 Accuracy: 0.681200
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.6028 Accuracy: 0.676400
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.6667 Accuracy: 0.681200
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.6226 Accuracy: 0.677800
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.6778 Accuracy: 0.669800
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.6462 Accuracy: 0.679400
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.5899 Accuracy: 0.678800
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.6583 Accuracy: 0.678800
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.6207 Accuracy: 0.678000
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.6508 Accuracy: 0.673800
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.6291 Accuracy: 0.679000
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.5808 Accuracy: 0.682800
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.6575 Accuracy: 0.682600
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.6191 Accuracy: 0.675200
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.6472 Accuracy: 0.677600
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.6253 Accuracy: 0.681000
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.5761 Accuracy: 0.682600
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.6630 Accuracy: 0.678000
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.6192 Accuracy: 0.683000
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.6349 Accuracy: 0.680200
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.6148 Accuracy: 0.681800
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.5800 Accuracy: 0.682400
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.6574 Accuracy: 0.684400
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.6106 Accuracy: 0.679600
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.6502 Accuracy: 0.673200
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.6135 Accuracy: 0.685600
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.5867 Accuracy: 0.672200

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6736806392669678

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
